# %%
pwd
# Out:
# 'C:\\Users\\saketh\\Desktop\\DMMidTerm_TeamID_11\\code'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is F82E-78BC
#
#  Directory of C:\Users\saketh\Desktop\DMMidTerm_TeamID_11\code
#
# 16-02-2020  23:37    <DIR>          .
# 16-02-2020  23:37    <DIR>          ..
# 16-02-2020  20:19    <DIR>          .ipynb_checkpoints
# 16-02-2020  23:37           144,390 data_cleaning.ipynb
# 16-02-2020  23:37           459,044 data_transformation.ipynb
# 16-02-2020  23:37         1,993,885 visualizations.ipynb
#                3 File(s)      2,597,319 bytes
#                3 Dir(s)  138,484,908,032 bytes free

# %% [markdown]
# # <span style='color:Black'> Converting state names to upper case  </span>

# %%
import pandas as pd

combined_csv = pd.read_csv("../data/combined_csv_missingval_mean.csv",encoding='iso-8859-1')
#converting all names to upper case for consistency
combined_csv['STATE'] = combined_csv['STATE'].str.upper()
#writing to a new file
combined_csv.to_csv("../data/combined_csv_missingval_mean_new.csv",encoding='iso-8859-1')
combined_csv.head()
# Out:
#    STATION CODE                                          LOCATIONS  \
# 0        1513.0  B W. - KRISHNA MURTHY, D.NO. 48-16-43 AUTONAGA...
# 1        1514.0  B/W. - VIJAY KUMAR AUTONAGAR VIJAYAWADA, KRISH...
# 2        1515.0  B/W. - NAGARAM(V), PALVONCHA, KHAMMAM DIST., A.P.
# 3        1516.0                   B W OF NAVLOK GARDENS NELLORE AP
# 4        1517.0         B/W. - TUNGBHADRA RIVER NEAR KURNOOL, A.P.
#
#             STATE  TEMPERATURE ºC : Min  TEMPERATURE ºC : Max  \
# 0  ANDHRA PRADESH                  23.0                  23.0
# 1  ANDHRA PRADESH                  23.0                  23.0
# 2  ANDHRA PRADESH                  19.0                  19.0
# 3  ANDHRA PRADESH                  29.0                  29.0
# 4  ANDHRA PRADESH                  27.0                  30.6
#
#    TEMPERATURE ºC : Mean  D.O. (mg/l) : Min : > 4 mg/l  \
# 0                   23.0                      5.241993
# 1                   23.0                      5.241993
# ...

# %% [markdown]
# # <span style='color:Black'> Analyzing original dataset </span>

# %%
import numpy as np
wq_data =pd.read_csv("../data/combined_csv_missingval_mean_new.csv",encoding='iso-8859-1')

small_set = wq_data.sample(10);

# %%
print("Sample data:\n")
small_set
# Out:
# Sample data:
#       Unnamed: 0  STATION CODE  \
# 84            84        2587.0
# 749          749        1302.0
# 730          730        1006.0
# 1254        1254        1267.0
# 28            28          26.0
# 980          980        1243.0
# 1019        1019        2115.0
# 755          755        2415.0
# 1113        1113        2765.0
# 1363        1363        2523.0
#
#                                               LOCATIONS             STATE  \
# 84                                             KHAGARIA             BIHAR
# 749                    BRAHMANI AT ROURKELA D/S, ODISHA            ODISHA
# 730                             BEAS AT D/S MANDI, H.P.  HIMACHAL PRADESH
# 1254                           IB AT SUNDARGARH, ODISHA            ODISHA
# 28                               Borewell at Vijayawada    ANDHRA PRADESH
# 980              NARMADA AT BHARUCH, ZADESHVAR, GUJARAT           GUJARAT
# 1019  RIVER TAPTI AT NEPA NAGAR 100 METRE D/S  AFTER...    MADHYA PRADESH
# ...

# %%
#no.of missing values each attribute

missing_data = wq_data.isnull().sum();
print("Number of missing data points (attribute wise):\n")
print(missing_data)
# Out:
# Number of missing data points (attribute wise):
#
# Unnamed: 0                                              0
# STATION CODE                                            0
# LOCATIONS                                               0
# STATE                                                   0
# TEMPERATURE ºC : Min                                    0
# TEMPERATURE ºC : Max                                    0
# TEMPERATURE ºC : Mean                                   0
# D.O. (mg/l) : Min : > 4 mg/l                            0
# D.O. (mg/l) : Max : > 4 mg/l                            0
# D.O. (mg/l) : Mean : > 4 mg/l                           0
# pH : Min : 6.5-8.5                                      0
# pH : Max : 6.5-8.5                                      0
# pH : Mean : 6.5-8.5                                     0
# CONDUCTIVITY (µmhos/cm) : Min                           0
# CONDUCTIVITY (µmhos/cm) : Max                           0
# ...

# %%
total_cells= np.product(wq_data.shape)
total_missing_values = missing_data.sum();

print("Percentage of missing data:" +str ( (total_missing_values/total_cells)*100) )
# Out:
# Percentage of missing data:0.0

# %% [markdown]
# # <span style='color:Black'> Filling missing values with column means  </span>

# %%
import pandas as pd
import numpy as np

wq_data =pd.read_csv("../data/complete_dataset.csv",encoding='iso-8859-1')

#replacing missing values with column means
means =wq_data.mean()

wq_data=wq_data.fillna(means)

#Records are deleted if no State is mentioned
missing_state=pd.notnull(wq_data['STATE'])
wq_final_data=wq_data[missing_state]

missing_data = wq_final_data.isnull().sum()
total_cells= np.product(wq_final_data.shape)
total_missing_values = missing_data.sum()

print("Total missing values:"+str(total_missing_values))
print("Percentage of missing data:" + str ( (total_missing_values/total_cells)*100) )

wq_final_data.to_csv("../data/combined_csv_missingval_mean.csv", index=False, encoding='iso-8859-1');
wq_final_data
# Out:
# Total missing values:0
# Percentage of missing data:0.0
#       STATION CODE                                          LOCATIONS  \
# 0           1513.0  B W. - KRISHNA MURTHY, D.NO. 48-16-43 AUTONAGA...
# 1           1514.0  B/W. - VIJAY KUMAR AUTONAGAR VIJAYAWADA, KRISH...
# 2           1515.0  B/W. - NAGARAM(V), PALVONCHA, KHAMMAM DIST., A.P.
# 3           1516.0                   B W OF NAVLOK GARDENS NELLORE AP
# 4           1517.0         B/W. - TUNGBHADRA RIVER NEAR KURNOOL, A.P.
# 5           1518.0                B/W. - NANDYAL, KURNOOL DIST., A.P.
# 6           1519.0                 B/W. - NAGIRI, CHITTOOR DIST., A.P
# 7           1520.0  B/W. - SWARNAMUKHI RIVER, SRIKALAHASTI, CHITTO...
# 8           1521.0  O/W. - NEAR RAMA TEMPLE , WARD NO.2 , MINDI , ...
# 9           1522.0                O/W. PEDDANUYYI - VIZIANAGARAM, A.P
# 10          1523.0  B/W. - NEAR M/S ANDHRA SUGARS LTD. , KOVVUR , ...
# 11          1524.0  O/W. -NEAR PARTAP NAGAR BRIIDGE -KAKINADA , E....
# ...
